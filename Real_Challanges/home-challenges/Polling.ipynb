# %% [markdown]
# # Democracy Works - Silas Lee

# %% [markdown]
# ### Imports, parsing test

# %%
import pandas as pd # data processing, Excel file I/O (e.g. pd.read_csv)

import usaddress
addr='974 Great Plain Avenue Needham MA 02492 USA CON-069 CT069'
usaddress.parse(addr)
# Out:
# [('974', 'AddressNumber'),
#  ('Great', 'StreetName'),
#  ('Plain', 'StreetName'),
#  ('Avenue', 'StreetNamePostType'),
#  ('Needham', 'PlaceName'),
#  ('MA', 'StateName'),
#  ('02492', 'ZipCode'),
#  ('USA', 'CountryName'),
#  ('CON-069', 'OccupancyIdentifier'),
#  ('CT069', 'OccupancyIdentifier')]

# %% [markdown]
# ### Read Addresses and create ID column

# %%
addresses = pd.read_excel('addresses.csv.xlsx')
addresses['ID'] = addresses['State'] + addresses['Precinct ID'].astype(str).str[-3:] #Create ID Column to match Precinct
display(addresses.head(10))
# Out:
#                       Street     Apt          City State         Zip  \
# 0              7 BEACON BLVD     NaN       PEABODY    MA  01960-6303
# 1              1847 TOWER DR     NaN     STOUGHTON    WI  53589-3539
# 2       4628 GREEN VALLEY RD     NaN     FAIRFIELD    CA  94534-1368
# 3                14 HALET ST     NaN      PORTLAND    ME  04102-1734
# 4  1606 BLACKBURN HEIGHTS DR     NaN     SEWICKLEY    PA  15143-8626
# 5              405 LAUREL PL     NaN         MACON    GA  31220-8761
# 6          1011 VALENCIA AVE     NaN  CORAL GABLES    FL  33134-5536
# 7               43 BOYDEN ST     NaN      BROCKTON    MA  02302-2303
# 8         1051 E STEARNS AVE  APT 36      LA HABRA    CA  90631-4857
# 9               10 RUSTIC DR     NaN   N BRUNSWICK    NJ  08902-4706
#
#   Precinct ID     ID
# 0     025-090  MA090
# 1     055-015  WI015
# 2     006-009  CA009
# 3     023-089  ME089
# 4     042-018  PA018
# 5     013-041  GA041
# 6     012-051  FL051
# 7     025-111  MA111
# 8     006-021  CA021
# 9     034-010  NJ010

# %% [markdown]
# ### Read Polling Addresses and change column names for merge

# %%
polling = pd.read_excel('precinct_polling_list.csv.xlsx')
polling.columns = ['Poll_street', 'Poll_city','Poll_state/zip', 'Poll_country', 'Precinct'] #to prevent duplicate column names
display(polling.head(10))
# Out:
#                                Poll_street    Poll_city Poll_state/zip  \
# 0                          288 York Street    New Haven       CT 06511
# 1            301-399 South Boulevard Drive   Bainbridge       GA 39819
# 2                   150-151 Tremont Street       Boston       MA 02111
# 3                    2395 Ingleside Avenue        Macon       GA 31204
# 4                     1007 Merchant Street     Ambridge       PA 15003
# 5                    859 Washington Avenue  Miami Beach       FL 33139
# 6  974 Great Plain Avenue Needham MA 02492          USA        MAS-006
# 7                     139 Lynnfield Street      Peabody       MA 01960
# 8                        180 Nassau Street    Princeton       NJ 08542
# 9               563 Carlsbad Village Drive     Carlsbad       CA 92008
#
#   Poll_country  Precinct
# 0          USA   CON-069
# 1          USA   GEO-062
# 2          USA   MAS-111
# 3          USA   GEO-041
# 4          USA   MAS-018
# 5          USA   FLO-051
# 6          NaN       NaN
# 7          USA   MAS-090
# 8          USA  NEWJ-010
# 9          USA   CAL-032

# %% [markdown]
# ### Create Polling Address column, address missing values

# %%
polling.fillna('', inplace=True) #for later parsing,s tring is necessary
polling['Polling Address'] = polling['Poll_street'].astype(str) + ' ' + polling['Poll_city'].astype(str) + ' ' + polling['Poll_state/zip'].astype(str) + ' ' + polling['Poll_country'] + ' ' + polling['Precinct']
display(polling.head(10))
# Out:
#                                Poll_street    Poll_city Poll_state/zip  \
# 0                          288 York Street    New Haven       CT 06511
# 1            301-399 South Boulevard Drive   Bainbridge       GA 39819
# 2                   150-151 Tremont Street       Boston       MA 02111
# 3                    2395 Ingleside Avenue        Macon       GA 31204
# 4                     1007 Merchant Street     Ambridge       PA 15003
# 5                    859 Washington Avenue  Miami Beach       FL 33139
# 6  974 Great Plain Avenue Needham MA 02492          USA        MAS-006
# 7                     139 Lynnfield Street      Peabody       MA 01960
# 8                        180 Nassau Street    Princeton       NJ 08542
# 9               563 Carlsbad Village Drive     Carlsbad       CA 92008
#
#   Poll_country  Precinct                                    Polling Address
# 0          USA   CON-069     288 York Street New Haven CT 06511 USA CON-069
# 1          USA   GEO-062  301-399 South Boulevard Drive Bainbridge GA 39...
# 2          USA   MAS-111  150-151 Tremont Street Boston MA 02111 USA MAS...
# 3          USA   GEO-041   2395 Ingleside Avenue Macon GA 31204 USA GEO-041
# 4          USA   MAS-018  1007 Merchant Street Ambridge PA 15003 USA MAS...
# 5          USA   FLO-051  859 Washington Avenue Miami Beach FL 33139 USA...
# 6                         974 Great Plain Avenue Needham MA 02492 USA MA...
# 7          USA   MAS-090  139 Lynnfield Street Peabody MA 01960 USA MAS-090
# 8          USA  NEWJ-010  180 Nassau Street Princeton NJ 08542 USA NEWJ-010
# 9          USA   CAL-032  563 Carlsbad Village Drive Carlsbad CA 92008 U...

# %% [markdown]
# ### Redistribute stray address labels in table

# %%
for index, row in polling.iterrows():
    if row['Precinct'] == '':
        street_address = ''
        city = ''
        state_zip = ''
        country = ''
        precinct = ''
        for part, part_type in usaddress.parse(row['Polling Address']):
            if part_type == "AddressNumber" or part_type == 'StreetNamePreDirectional' or part_type == 'StreetName' or part_type == 'StreetNamePostType':
                street_address += part
                street_address += ' '
            elif part_type == 'PlaceName':
                city += part
                city += ' '
            elif part_type == "StateName" or part_type == 'ZipCode':
                state_zip += part
                state_zip += ' '
            elif part_type == 'CountryName':
                country += part
                country += ' '
            elif part_type == 'OccupancyIdentifier':
                precinct += part
                precinct += ' '
       
        row['Poll_street'] = street_address.strip()
        row['Poll_city'] = city.strip()
        row['Poll_state/zip'] = state_zip.strip()
        row['Poll_country'] = country.strip()
        row['Precinct'] = precinct.strip()
        
display(polling)
# Out:
#                         Poll_street      Poll_city Poll_state/zip  \
# 0                   288 York Street      New Haven       CT 06511
# 1     301-399 South Boulevard Drive     Bainbridge       GA 39819
# 2            150-151 Tremont Street         Boston       MA 02111
# 3             2395 Ingleside Avenue          Macon       GA 31204
# 4              1007 Merchant Street       Ambridge       PA 15003
# 5             859 Washington Avenue    Miami Beach       FL 33139
# 6            974 Great Plain Avenue        Needham       MA 02492
# 7              139 Lynnfield Street        Peabody       MA 01960
# 8                 180 Nassau Street      Princeton       NJ 08542
# 9        563 Carlsbad Village Drive       Carlsbad       CA 92008
# 10            5110-5140 Main Street        Buffalo       NY 14221
# 11             2048 Hillside Avenue  New Hyde Park       NY 11040
# 12              108 West 2nd Street    Los Angeles       CA 90012
# 13                 29 Godwin Avenue      Ridgewood       NJ 07450
# 14   1093 Hemphill Avenue Northwest        Atlanta       GA 30318
# 15                  328 Boston Road      Billerica       MA 01821
# 16         1875 South Bascom Avenue       Campbell       CA 95008
# 17             6444-6544 Georgia 85      Riverdale       GA 30274
# 18               443 Emerson Street      Palo Alto       CA 94301
# 19    484 Moreland Avenue Northeast        Atlanta       GA 30307
# 20             210 Blake Road North        Hopkins       MN 55343
# 21            311 East State Street       Rockford       IL 61104
# 22        1149 East Southern Avenue           Mesa       AZ 85204
# 23           1782 Massachusetts Ave      Cambridge       MA 02140
# 24          1101 South Joyce Street      Arlington       VA 22202
# 25              574 Congress Street       Portland       ME 04101
# 26                 114 State Street        Madison       WI 53703
# 27  9600-9708 West Linebaugh Avenue      Westchase       FL 33626
# 28            3085 Jefferson Street           Napa       CA 94559
# 29            2313 Frankford Avenue   Philadelphia       PA 19125
# 30           2035 East North Avenue      Milwaukee       WI 53211
# 31              110 Community Drive        Augusta       ME 04330
# 32                  114 10th Avenue       New York       NY 10011
#
#    Poll_country  Precinct                                    Polling Address
# 0           USA   CON-069     288 York Street New Haven CT 06511 USA CON-069
# 1           USA   GEO-062  301-399 South Boulevard Drive Bainbridge GA 39...
# 2           USA   MAS-111  150-151 Tremont Street Boston MA 02111 USA MAS...
# 3           USA   GEO-041   2395 Ingleside Avenue Macon GA 31204 USA GEO-041
# 4           USA   MAS-018  1007 Merchant Street Ambridge PA 15003 USA MAS...
# 5           USA   FLO-051  859 Washington Avenue Miami Beach FL 33139 USA...
# 6           USA   MAS-006  974 Great Plain Avenue Needham MA 02492 USA MA...
# 7           USA   MAS-090  139 Lynnfield Street Peabody MA 01960 USA MAS-090
# 8           USA  NEWJ-010  180 Nassau Street Princeton NJ 08542 USA NEWJ-010
# 9           USA   CAL-032  563 Carlsbad Village Drive Carlsbad CA 92008 U...
# 10          USA  NEWY-072  5110-5140 Main Street Buffalo NY 14221 USA NEW...
# 11          USA  NEWY-099  2048 Hillside Avenue New Hyde Park NY 11040 US...
# 12          USA   CAL-021  108 West 2nd Street Los Angeles CA 90012 USA C...
# 13          USA  NEWJ-000  29 Godwin Avenue Ridgewood NJ 07450 USA NEWJ-000
# 14          USA   GEO-000  1093 Hemphill Avenue Northwest Atlanta GA 3031...
# 15          USA   MAS-010     328 Boston Road Billerica MA 01821 USA MAS-010
# 16          USA   CAL-000  1875 South Bascom Avenue Campbell CA 95008 USA...
# 17          USA   GEO-009  6444-6544 Georgia 85 Riverdale GA 30274 USA GE...
# 18          USA   CAL-041  443 Emerson Street Palo Alto CA 94301 USA CAL-041
# 19          USA   GEO-055  484 Moreland Avenue Northeast Atlanta GA 30307...
# 20          USA   MIN-028  210 Blake Road North Hopkins MN 55343 USA MIN-028
# 21          USA   ILL-038  311 East State Street Rockford IL 61104 USA IL...
# 22          USA   ARI-067  1149 East Southern Avenue Mesa AZ 85204 USA AR...
# 23          USA   MAS-070  1782 Massachusetts Ave Cambridge MA 02140 USA ...
# 24          USA   VIR-092  1101 South Joyce Street Arlington VA 22202 USA...
# 25          USA   MAI-089  574 Congress Street Portland ME 04101 USA MAI-089
# 26          USA   WIS-015      114 State Street Madison WI 53703 USA WIS-015
# 27          USA   FLO--67  9600-9708 West Linebaugh Avenue Westchase FL 3...
# 28          USA   CAL-009    3085 Jefferson Street Napa CA 94559 USA CAL-009
# 29          USA   PEN-097  2313 Frankford Avenue Philadelphia PA 19125 US...
# 30          USA   WIS-067  2035 East North Avenue Milwaukee WI 53211 USA ...
# 31          USA   MAI-027   110 Community Drive Augusta ME 04330 USA MAI-027
# 32          USA  NEWY-087     114 10th Avenue New York NY 10011 USA NEWY-087

# %% [markdown]
# ### Now that Polling addresses are cleaned, drop the full address column and create polling ID to match Addresses

# %%
polling = polling.drop(['Polling Address'], axis=1)
polling['ID'] = polling['Poll_state/zip'].astype(str).str[:2] + polling['Precinct'].astype(str).str[-3:] #Create ID Column to match Precinct
display(polling.head())
# Out:
#                      Poll_street   Poll_city Poll_state/zip Poll_country  \
# 0                288 York Street   New Haven       CT 06511          USA
# 1  301-399 South Boulevard Drive  Bainbridge       GA 39819          USA
# 2         150-151 Tremont Street      Boston       MA 02111          USA
# 3          2395 Ingleside Avenue       Macon       GA 31204          USA
# 4           1007 Merchant Street    Ambridge       PA 15003          USA
#
#   Precinct     ID
# 0  CON-069  CT069
# 1  GEO-062  GA062
# 2  MAS-111  MA111
# 3  GEO-041  GA041
# 4  MAS-018  PA018

# %% [markdown]
# ### Merge the two tables, save as CSV file

# %%
merged = pd.merge(addresses, polling, how='left', on= 'ID')
display(merged)
merged.to_csv('silasleemerged.csv', index_label=False)
# Out:
#                        Street     Apt           City State         Zip  \
# 0               7 BEACON BLVD     NaN        PEABODY    MA  01960-6303
# 1               1847 TOWER DR     NaN      STOUGHTON    WI  53589-3539
# 2        4628 GREEN VALLEY RD     NaN      FAIRFIELD    CA  94534-1368
# 3                 14 HALET ST     NaN       PORTLAND    ME  04102-1734
# 4   1606 BLACKBURN HEIGHTS DR     NaN      SEWICKLEY    PA  15143-8626
# 5               405 LAUREL PL     NaN          MACON    GA  31220-8761
# 6           1011 VALENCIA AVE     NaN   CORAL GABLES    FL  33134-5536
# 7                43 BOYDEN ST     NaN       BROCKTON    MA  02302-2303
# 8          1051 E STEARNS AVE  APT 36       LA HABRA    CA  90631-4857
# 9                10 RUSTIC DR     NaN    N BRUNSWICK    NJ  08902-4706
# 10            719 ROSEWOOD DR     NaN      PALO ALTO    CA  94303-3638
# 11          5373 FOXHOUND WAY     NaN      SAN DIEGO    CA  92130-4834
# 12           2 Gunderson Road     NaN     WILMINGTON    MA  01887-1520
# 13             1272 BEACON ST   APT 1      BROOKLINE    MA  02446-3717
# 14           300 CHURCHILL RD     NaN        TEANECK    NJ  07666-3007
# 15        439 MATHER MAIL CTR     NaN      CAMBRIDGE    MA  02138-7570
# 16          1228 E KRAMER CIR     NaN           MESA    AZ  85203-1941
# 17            5261 LOCHLOY DR     NaN          EDINA    MN  55436-2023
# 18          22 PIPING ROCK DR     NaN       OSSINING    NY  10562-2349
# 19          10338 MILLPORT DR     NaN          TAMPA    FL  33626-1706
# 20          1244 FAIRVIEW AVE     NaN      HAVERTOWN    PA  19083-4219
# 21       193 WINDING RIVER RD     NaN      WELLESLEY    MA  02482-7319
# 22           9650 THACKERY SQ     NaN        FAIRFAX    VA  22032-2537
# 23      390 WINTHROP MAIL CTR     NaN      CAMBRIDGE    MA  02138-7578
# 24           75 HUNTINGTON RD     NaN         NEWTON    MA  02458-2416
# 25              15 HAMPTON DR     NaN     WOODBRIDGE    CT  06525-1540
# 26              19 O KEEFE RD     NaN    BRIDGEWATER    NJ  08807-5694
# 27          49 CLOCK TOWER LN     NaN   OLD WESTBURY    NY  11568-1031
# 28                18 ACORN LN     NaN    SCARBOROUGH    ME  04074-7518
# 29             2835 NORMAN DR     NaN     BROOKFIELD    WI  53045-3015
# 30          17635 FAIRWAY CIR     NaN   MONTE SERENO    CA  95030-2212
# 31                25 DAISY LN     NaN        AMHERST    NY  14228-1262
# 32             107 REGENTS SQ     NaN  PEACHTREE CTY    GA  30269-4279
# 33        725 GARIBALDI ST SW     NaN        ATLANTA    GA  30310-2170
# 34        1006 CREST RIDGE DR     NaN     EAST POINT    GA  30344-5764
# 35           1404 NELSON BLVD     NaN       ROCKFORD    IL  61104-4718
# 36               916 JULIA PL     NaN     BAINBRIDGE    GA  39819-4816
# 37          3375 RILMAN RD NW     NaN        ATLANTA    GA  30327-1507
# 38          37 MORANG COVE RD     NaN      NOBLEBORO    ME  04555-9506
# 39         274 CABOT MAIL CTR     NaN      CAMBRIDGE    MA  02138-7535
# 40               6 FOX RUN LN     NaN     MARBLEHEAD    MA  01945-2169
#
#    Precinct ID     ID                     Poll_street      Poll_city  \
# 0      025-090  MA090            139 Lynnfield Street        Peabody
# 1      055-015  WI015                114 State Street        Madison
# 2      006-009  CA009           3085 Jefferson Street           Napa
# 3      023-089  ME089             574 Congress Street       Portland
# 4      042-018  PA018            1007 Merchant Street       Ambridge
# 5      013-041  GA041           2395 Ingleside Avenue          Macon
# 6      012-051  FL051           859 Washington Avenue    Miami Beach
# 7      025-111  MA111          150-151 Tremont Street         Boston
# 8      006-021  CA021             108 West 2nd Street    Los Angeles
# 9      034-010  NJ010               180 Nassau Street      Princeton
# 10     006-041  CA041              443 Emerson Street      Palo Alto
# 11     006-032  CA032      563 Carlsbad Village Drive       Carlsbad
# 12     048-010  MA010                 328 Boston Road      Billerica
# 13     025-111  MA111          150-151 Tremont Street         Boston
# 14     034-087  NJ087                             NaN            NaN
# 15     025-070  MA070          1782 Massachusetts Ave      Cambridge
# 16     004-067  AZ067       1149 East Southern Avenue           Mesa
# 17     027-028  MN028            210 Blake Road North        Hopkins
# 18     036-000  NY000                             NaN            NaN
# 19     012-067  FL067                             NaN            NaN
# 20     042-097  PA097           2313 Frankford Avenue   Philadelphia
# 21     025-006  MA006          974 Great Plain Avenue        Needham
# 22     051-092  VA092         1101 South Joyce Street      Arlington
# 23     025-070  MA070          1782 Massachusetts Ave      Cambridge
# 24     025-011  MA011                             NaN            NaN
# 25     009-069  CT069                 288 York Street      New Haven
# 26     034-010  NJ010               180 Nassau Street      Princeton
# 27     036-099  NY099            2048 Hillside Avenue  New Hyde Park
# 28     023-089  ME089             574 Congress Street       Portland
# 29     055-067  WI067          2035 East North Avenue      Milwaukee
# 30     006-000  CA000        1875 South Bascom Avenue       Campbell
# 31     036-072  NY072           5110-5140 Main Street        Buffalo
# 32     013-009  GA009            6444-6544 Georgia 85      Riverdale
# 33     013-000  GA000  1093 Hemphill Avenue Northwest        Atlanta
# 34     013-055  GA055   484 Moreland Avenue Northeast        Atlanta
# 35     017-038  IL038           311 East State Street       Rockford
# 36     013-062  GA062   301-399 South Boulevard Drive     Bainbridge
# 37     013-000  GA000  1093 Hemphill Avenue Northwest        Atlanta
# 38     023-027  ME027             110 Community Drive        Augusta
# 39     025-076  MA076                             NaN            NaN
# 40     025-090  MA090            139 Lynnfield Street        Peabody
#
#    Poll_state/zip Poll_country  Precinct
# 0        MA 01960          USA   MAS-090
# 1        WI 53703          USA   WIS-015
# 2        CA 94559          USA   CAL-009
# 3        ME 04101          USA   MAI-089
# 4        PA 15003          USA   MAS-018
# 5        GA 31204          USA   GEO-041
# 6        FL 33139          USA   FLO-051
# 7        MA 02111          USA   MAS-111
# 8        CA 90012          USA   CAL-021
# 9        NJ 08542          USA  NEWJ-010
# 10       CA 94301          USA   CAL-041
# 11       CA 92008          USA   CAL-032
# 12       MA 01821          USA   MAS-010
# 13       MA 02111          USA   MAS-111
# 14            NaN          NaN       NaN
# 15       MA 02140          USA   MAS-070
# 16       AZ 85204          USA   ARI-067
# 17       MN 55343          USA   MIN-028
# 18            NaN          NaN       NaN
# 19            NaN          NaN       NaN
# 20       PA 19125          USA   PEN-097
# 21       MA 02492          USA   MAS-006
# 22       VA 22202          USA   VIR-092
# 23       MA 02140          USA   MAS-070
# 24            NaN          NaN       NaN
# 25       CT 06511          USA   CON-069
# 26       NJ 08542          USA  NEWJ-010
# 27       NY 11040          USA  NEWY-099
# 28       ME 04101          USA   MAI-089
# 29       WI 53211          USA   WIS-067
# 30       CA 95008          USA   CAL-000
# 31       NY 14221          USA  NEWY-072
# 32       GA 30274          USA   GEO-009
# 33       GA 30318          USA   GEO-000
# 34       GA 30307          USA   GEO-055
# 35       IL 61104          USA   ILL-038
# 36       GA 39819          USA   GEO-062
# 37       GA 30318          USA   GEO-000
# 38       ME 04330          USA   MAI-027
# 39            NaN          NaN       NaN
# 40       MA 01960          USA   MAS-090
